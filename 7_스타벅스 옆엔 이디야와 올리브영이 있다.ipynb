# %% [markdown]
# # **1. 스타벅스 옆엔 이디야와 올리브영이 있다?**
# [관련 기사 링크 - 프랜차이즈 브랜드 立地<입지> 선택의 법칙… 스타벅스 옆엔 이디야가 있다?](https://kid.chosun.com/site/data/html_dir/2022/06/02/2022060202963.html)

# %% [markdown]
# # **2. 스타벅스 정보 크롤링**
# > 7_스타벅스 옆엔 이디야와 올리브영이 있다.py<br>크롤링 파일입니다. 이 파일을 참고하세요

# %%
import pandas as pd

df_starbucks = pd.read_csv('./data/7_data/starbucks_seoul.csv')
df_starbucks
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[104], line 3
#       1 import pandas as pd
# ----> 3 df_starbucks = pd.read_csv('./data/7_data/starbucks_seoul.csv')
#       4 df_starbucks
#
# File c:\Users\ohjih\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ohjih\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\ohjih\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ohjih\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\ohjih\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/7_data/starbucks_seoul.csv'

# %% [markdown]
# # **3. 데이터 전처리**

# %%
df_starbucks = df_starbucks.set_axis(['지점명', '지점주소', '지점위도', '지점경도'], axis=1).reset_index(drop=True)
df_starbucks
# Out:
#            지점명                                   지점주소       지점위도        지점경도
# 0    역삼아레나빌딩                  서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1     논현역사거리                 서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2    신사역성일빌딩                 서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3     국기원사거리                 서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4     대치재경빌딩               서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ..         ...                                    ...        ...         ...
# 655      상봉역                  서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 656       묵동    서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 657      망우동                  서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 658      양원역                서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 659      중화역                     서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [660 rows x 4 columns]

# %%
df = pd.read_csv('./data/5_data/소상공인시장진흥공단_상가(상권)정보_서울_202506.csv', low_memory=False)
df
# Out:
#                       상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220803882516     피어리스양품  NaN        G2       소매      G209
# 1       MA010120220803882799    삼보금속인쇄소  NaN        M1    과학·기술      M114
# 2       MA010120220800132710     한동규법무사  NaN        M1    과학·기술      M103
# 3       MA010120220809677897  진앤케이엔지니어링  NaN        M1    과학·기술      M109
# 4       MA010120220809678175        까페인  NaN        I2       음식      I212
# ...                      ...        ...  ...       ...      ...       ...
# 536110  MA010120220811815207     무명고시식당  NaN        I2       음식      I201
# 536111  MA010120220812812834      에스와이엘  NaN        I2       음식      I204
# 536112  MA010120220812814040        라플라  NaN        G2       소매      G209
# 536113  MA010120220808409779       목동기원  NaN        R1   예술·스포츠      R104
# 536114  MA010120220803778725         한결  NaN        S2    수리·개인      S207
#
#            상권업종중분류명 상권업종소분류코드         상권업종소분류명 표준산업분류코드  ...  \
# 0       섬유·의복·신발 소매    G20902        여성 의류 소매업   G47412  ...
# 1           인쇄·제품제작    M11401     명함/간판/광고물 제작   C18111  ...
# 2             법무관련     M10303              법무사   M71103  ...
# 3            기술 서비스    M10999    기타 엔지니어링 서비스업   M72129  ...
# 4             비알코올     I21201               카페   I56221  ...
# ...             ...       ...              ...      ...  ...
# 536110           한식    I20101           백반/한정식   I56111  ...
# 536111          서양식    I20401              경양식   I56123  ...
# 536112  섬유·의복·신발 소매    G20902        여성 의류 소매업   G47412  ...
# 536113       유원지·오락    R10414  바둑/장기/체스 경기 운영업   R91293  ...
# 536114        이용·미용    S20701              미용실   S96112  ...
#
#                            건물관리번호         건물명                 도로명주소   구우편번호  \
# 0       1129013700100070112014695        피어리스   서울특별시 성북구 화랑로25길 27  136865
# 1       1135010200102980014017775         NaN     서울특별시 노원구 광운로 135  139917
# 2       1114016600100550004022519        배재빌딩     서울특별시 중구 서소문로 103  100738
# 3       1156011400100740004000001  금강펜테리움IT타워    서울특별시 영등포구 당산로 171  150806
# 4       1154510100100600029015862         NaN    서울특별시 금천구 가산로9길 80  153801
# ...                           ...         ...                   ...     ...
# 536110  1162010200115320017007003         NaN   서울특별시 관악구 호암로22길 15  151895
# 536111  1168010700105890019011146        GIOG  서울특별시 강남구 논현로152길 35  135893
# 536112  1168010700106540007027114       브로스빌딩  서울특별시 강남구 도산대로53길 19  135897
# 536113  1147010100101180020005571         NaN      서울특별시 양천구 신목로 86  158849
# 536114  1121510700100940061017703         NaN     서울특별시 광진구 능동로 163  143915
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 0       2773  NaN    1  NaN  127.051622  37.609666
# 1       1885  NaN  NaN  NaN  127.057933  37.628350
# 2       4516  NaN  NaN  NaN  126.972666  37.563021
# 3       7217  NaN  NaN  NaN  126.898099  37.529967
# 4       8513  NaN    1  NaN  126.887840  37.475799
# ...      ...  ...  ...  ...         ...        ...
# 536110  8812  NaN    1  NaN  126.933587  37.469049
# 536111  6024  NaN    2  NaN  127.030928  37.521781
# 536112  6019  NaN    5  NaN  127.038372  37.524419
# 536113  8009  NaN    8  NaN  126.874773  37.522322
# 536114  5010  NaN    1  NaN  127.072930  37.545387
#
# [536115 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536115 entries, 0 to 536114
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     536115 non-null  object
#  1   상호명        536115 non-null  object
#  2   지점명        47586 non-null   object
#  3   상권업종대분류코드  536115 non-null  object
#  4   상권업종대분류명   536115 non-null  object
#  5   상권업종중분류코드  536115 non-null  object
#  6   상권업종중분류명   536115 non-null  object
#  7   상권업종소분류코드  536115 non-null  object
#  8   상권업종소분류명   536115 non-null  object
#  9   표준산업분류코드   535912 non-null  object
#  10  표준산업분류명    535912 non-null  object
#  11  시도코드       536115 non-null  int64
#  12  시도명        536115 non-null  object
#  13  시군구코드      536115 non-null  int64
#  14  시군구명       536115 non-null  object
#  15  행정동코드      536115 non-null  int64
#  16  행정동명       536115 non-null  object
#  17  법정동코드      536115 non-null  int64
#  18  법정동명       536115 non-null  object
#  19  지번코드       536115 non-null  int64
#  20  대지구분코드     536115 non-null  int64
#  21  대지구분명      536115 non-null  object
#  22  지번본번지      536063 non-null  float64
#  23  지번부번지      444966 non-null  float64
#  24  지번주소       536115 non-null  object
#  25  도로명코드      536115 non-null  int64
#  26  도로명        536115 non-null  object
#  27  건물본번지      536114 non-null  float64
#  28  건물부번지      70107 non-null   float64
#  29  건물관리번호     536114 non-null  object
#  30  건물명        263846 non-null  object
#  31  도로명주소      536115 non-null  object
#  32  구우편번호      536115 non-null  int64
#  33  신우편번호      536115 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        368125 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         536115 non-null  float64
#  38  위도         536115 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 159.5+ MB

# %%
shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']

# %%
# 메가커피(메가엠지씨) 데이터 필터링
# contains(): 특정 문자열 포함 여부에 따라 True, False를 반환
# case=False: 대소문자를 구분하지 않겠다는 설정
# na=False: 결측치(NaN) 처리. 결측치가 있는 경우 False로 간주하여 결과에 포함되지 않음
df[df['상호명'].str.contains('메가엠지씨', case=False, na=False)]
# Out:
#                       상가업소번호             상호명      지점명 상권업종대분류코드 상권업종대분류명  \
# 1148    MA010120220807111048  메가엠지씨커피홍제홍은벽산점      NaN        I2       음식
# 6164    MA010120220808706104       메가엠지씨커피대림     사거리점        I2       음식
# 6239    MA010120220809781722         메가엠지씨커피  서울대입구역점        I2       음식
# 6650    MA010120220808598525  메가엠지씨커피잠실트리지움점      NaN        I2       음식
# 6891    MA0101202504A0051153       메가엠지씨커피길음      동부점        I2       음식
# ...                      ...             ...      ...       ...      ...
# 528715  MA010120220810453817      메가엠지씨커피오목교      중앙점        I2       음식
# 530079  MA010120220811868020      메가엠지씨커피촬영소     사거리점        I2       음식
# 531733  MA010120220813786743     메가엠지씨커피회기역점      NaN        I2       음식
# 532082  MA010120220813628416    메가엠지씨커피광운대역점      NaN        I2       음식
# 532382  MA010120220811954581       메가엠지씨커피서울      시청점        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 1148        I212    비알코올     I21201       카페   I56221  ...
# 6164        I212    비알코올     I21201       카페   I56221  ...
# 6239        I212    비알코올     I21201       카페   I56221  ...
# 6650        I212    비알코올     I21201       카페   I56221  ...
# 6891        I212    비알코올     I21201       카페   I56221  ...
# ...          ...      ...       ...      ...      ...  ...
# 528715      I212    비알코올     I21201       카페   I56221  ...
# 530079      I212    비알코올     I21201       카페   I56221  ...
# 531733      I212    비알코올     I21201       카페   I56221  ...
# 532082      I212    비알코올     I21201       카페   I56221  ...
# 532382      I212    비알코올     I21201       카페   I56221  ...
#
#                            건물관리번호      건물명                 도로명주소   구우편번호  \
# 1148    1141011800100480069013185      NaN   서울특별시 서대문구 홍은중앙로 33  120101
# 6164    1156013300109900004003606     대진빌딩   서울특별시 영등포구 시흥대로 629  150823
# 6239    1162010100108590017000003  관악위버폴리스     서울특별시 관악구 관악로 195  151811
# 6650    1171010100102420011001131      NaN   서울특별시 송파구 삼전로13길 22  138864
# 6891    1129013400111430000024479       좌측      서울특별시 성북구 삼양로 62  136801
# ...                           ...      ...                   ...     ...
# 528715  1147010200109330000021210    삼익아파트  서울특별시 양천구 목동동로12길 45  158820
# 530079  1123010500100020146019629      NaN   서울특별시 동대문구 답십리로 233  130800
# 531733  1123010900103190001009743      NaN    서울특별시 동대문구 회기로 194  130876
# 532082  1135010200104100007019107     동우빌딩     서울특별시 노원구 석계로 103  139846
# 532382  1114010200100590002000001      NaN       서울특별시 중구 다동길 34  100180
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 1148    3611  NaN    1  NaN  126.946317  37.594411
# 6164    7444  NaN    1  NaN  126.905664  37.488636
# 6239    8745  NaN    1  NaN  126.953101  37.482564
# 6650    5566  NaN    1  NaN  127.087902  37.507733
# 6891    2731  NaN    1  NaN  127.023353  37.608612
# ...      ...  ...  ...  ...         ...        ...
# 528715  8007  NaN    1  NaN  126.876367  37.522585
# 530079  2535  NaN    1  NaN  127.066086  37.572961
# 531733  2446  NaN    1  NaN  127.057360  37.589842
# 532082  1893  NaN    1  NaN  127.060716  37.622843
# 532382  4522  NaN  NaN  NaN  126.981165  37.567816
#
# [790 rows x 39 columns]

# %%
df[df['상호명'].str.contains('메가커피', case=False, na=False)]
# Out:
#                       상가업소번호           상호명    지점명 상권업종대분류코드 상권업종대분류명  \
# 13386   MA0101202209A0061331          메가커피   발산역점        I2       음식
# 25719   MA010120220809673319        메가커피신길    중앙점        I2       음식
# 58367   MA010120220800186190     식빵은여기메가커피    NaN        I2       음식
# 65146   MA010120220808157025     메가커피노량진역점    NaN        I2       음식
# 70857   MA010120220808836788      메가커피고투몰점    NaN        I2       음식
# 72217   MA010120220813125772     메가커피수락산역점    NaN        I2       음식
# 80159   MA010120220808463723          메가커피    NaN        I2       음식
# 81295   MA010120220807070602          메가커피    NaN        I2       음식
# 81636   MA010120220812511902          메가커피    공덕점        I2       음식
# 82961   MA010120220803387874        메가커피신곡    시장점        I2       음식
# 83722   MA010120220804149613          메가커피    장안점        I2       음식
# 90843   MA010120220808069247       메가커피신도봉    시장점        I2       음식
# 91998   MA010120220808992892    메가커피북한산정릉점    NaN        I2       음식
# 110748  MA010120220810024637          메가커피   왕십리점        I2       음식
# 112335  MA010120220804156243     메가커피신도림역점    NaN        I2       음식
# 114910  MA010120220813957016          메가커피   화곡역점        I2       음식
# 117575  MA010120220802241927          메가커피    마곡점        I2       음식
# 126638  MA010120220812962899  메가커피공덕SK리더스뷰    NaN        I2       음식
# 160271  MA010120220803145703        메가커피현대    시장점        I2       음식
# 162631  MA010120220808147311      메가커피수색자이    NaN        I2       음식
# 169002  MA010120220810074917     메가커피사가정역점    NaN        I2       음식
# 171902  MA010120220811858271      메가커피상계역점    NaN        I2       음식
# 202849  MA010120220800505619         메가커피우    장산점        I2       음식
# 206169  MA010120220812196839     메가커피문정로데오    NaN        I2       음식
# 253340  MA010120220806689213        메가커피이수    태평점        I2       음식
# 258312  MA010120220814193356      메가커피동소문점    NaN        I2       음식
# 276209  MA0101202409A0144201        메가커피잠실    지하점        I2       음식
df_shop = df.copy()

# %%
# shop = ['이디야', '이디아커피', '올리브영', '컴포즈커피', '빽다방', '백다방', '메가커피', '메가엠지씨', '메가MGC']
# 이디야|이디아커피|올리브영|컴포즈커피|빽다방|백다방|메가커피|메가엠지씨|메가MGC
# extract(): 특정 문자열을 포함하고 있으면 그 문자열을 반환, 포함하고 있지 않으면 NaN을 반환
df_shop['상호명'] = df_shop['상호명'].str.extract('({})'.format('|'.join(shop)))
df_shop['상호명']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 536110    NaN
# 536111    NaN
# 536112    NaN
# 536113    NaN
# 536114    NaN
# Name: 상호명, Length: 536115, dtype: object

# %%
df_shop = df_shop.dropna(subset=['상호명']).iloc[:, [0, 1, 14, 37, 38]].reset_index(drop=True)
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220805286683  컴포즈커피   도봉구  127.039395  37.640295
# 1     MA010120220807111048  메가엠지씨  서대문구  126.946317  37.594411
# 2     MA010120220808328868    빽다방   강동구  127.127661  37.549782
# 3     MA010120220809340836  컴포즈커피   광진구  127.084490  37.560876
# 4     MA010120220803663595    이디야   중랑구  127.074868  37.593328
# ...                    ...    ...   ...         ...        ...
# 2239  MA010120220802281662    빽다방   성동구  127.057133  37.545143
# 2240  MA010120220800458310  컴포즈커피    중구  126.990323  37.563997
# 2241  MA010120220806666628  컴포즈커피   마포구  126.914912  37.549190
# 2242  MA010120220812770796  컴포즈커피   강동구  127.172769  37.549842
# 2243  MA010120220806486938    이디야   광진구  127.078984  37.555582
#
# [2244 rows x 5 columns]

# %%
# 상호명 통일
df_shop['상호명'] = df_shop['상호명'].str.replace('메가엠지씨', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('메가MGC', '메가커피', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('이디아커피', '이디야', regex=False)
df_shop['상호명'] = df_shop['상호명'].str.replace('백다방', '빽다방', regex=False)
df_shop
# Out:
#                     상가업소번호    상호명  시군구명          경도         위도
# 0     MA010120220805286683  컴포즈커피   도봉구  127.039395  37.640295
# 1     MA010120220807111048   메가커피  서대문구  126.946317  37.594411
# 2     MA010120220808328868    빽다방   강동구  127.127661  37.549782
# 3     MA010120220809340836  컴포즈커피   광진구  127.084490  37.560876
# 4     MA010120220803663595    이디야   중랑구  127.074868  37.593328
# ...                    ...    ...   ...         ...        ...
# 2239  MA010120220802281662    빽다방   성동구  127.057133  37.545143
# 2240  MA010120220800458310  컴포즈커피    중구  126.990323  37.563997
# 2241  MA010120220806666628  컴포즈커피   마포구  126.914912  37.549190
# 2242  MA010120220812770796  컴포즈커피   강동구  127.172769  37.549842
# 2243  MA010120220806486938    이디야   광진구  127.078984  37.555582
#
# [2244 rows x 5 columns]

# %%
df_shop[df_shop['상호명'].str.contains('메가커피|메가MGC|메가엠지씨', na=False)]
# Out:
#                     상가업소번호   상호명  시군구명          경도         위도
# 1     MA010120220807111048  메가커피  서대문구  126.946317  37.594411
# 13    MA010120220808706104  메가커피  영등포구  126.905664  37.488636
# 14    MA010120220809781722  메가커피   관악구  126.953101  37.482564
# 16    MA010120220808598525  메가커피   송파구  127.087902  37.507733
# 17    MA0101202504A0051153  메가커피   성북구  127.023353  37.608612
# ...                    ...   ...   ...         ...        ...
# 2224  MA010120220811868020  메가커피  동대문구  127.066086  37.572961
# 2225  MA010120220802678209  메가커피   송파구  127.122108  37.482312
# 2230  MA010120220813786743  메가커피  동대문구  127.057360  37.589842
# 2231  MA010120220813628416  메가커피   노원구  127.060716  37.622843
# 2232  MA010120220811954581  메가커피    중구  126.981165  37.567816
#
# [839 rows x 5 columns]

# %%
print(df_shop.shape)
print(df_starbucks.shape)
# Out:
# (2244, 5)
# (660, 4)

# %%
df_cross = df_shop.merge(df_starbucks, how='cross')
df_cross
# Out:
#                        상가업소번호    상호명 시군구명          경도         위도        지점명  \
# 0        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295  역삼아레나빌딩
# 1        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   논현역사거리
# 2        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295  신사역성일빌딩
# 3        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   국기원사거리
# 4        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   대치재경빌딩
# ...                       ...    ...  ...         ...        ...        ...
# 1481035  MA010120220806486938    이디야  광진구  127.078984  37.555582      상봉역
# 1481036  MA010120220806486938    이디야  광진구  127.078984  37.555582       묵동
# 1481037  MA010120220806486938    이디야  광진구  127.078984  37.555582      망우동
# 1481038  MA010120220806486938    이디야  광진구  127.078984  37.555582      양원역
# 1481039  MA010120220806486938    이디야  광진구  127.078984  37.555582      중화역
#
#                                           지점주소       지점위도        지점경도
# 0                      서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1                     서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2                     서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3                     서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4                   서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ...                                        ...        ...         ...
# 1481035                서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 1481036  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 1481037                서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 1481038              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 1481039                   서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
# [1481040 rows x 9 columns]

# %% [markdown]
# # **4. 하버사인 공식**
# Haversine 공식은 구체(구면) 위의 두 점(위도와 경도로 표시됨) 사이의 최단 거리(대원 거리, great-circle distance)를 계산하는 방법입니다. 이 공식은 GPS 좌표(위도와 경도)를 활용하여 지구 표면 위의 거리 계산에 널리 사용됩니다.
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FSrWGW%2FbtsLpNU6kSG%2FAAAAAAAAAAAAAAAAAAAAACWyPfRAMbpe0b_v6ut8rDPwdQDwSdWFmpo2ovU3Wj0f%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1764514799%26allow_ip%3D%26allow_referer%3D%26signature%3DYwmvd7pR1rCEo4UGv28ScN8dl7I%253D">

# %%
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (2.9.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from haversine import haversine

# %%
df_cross['거리'] = df_cross.apply(lambda x: haversine([x['위도'], x['경도']], [x['지점위도'], x['지점경도']], unit='m'), axis=1)
df_cross
# Out:
#                        상가업소번호    상호명 시군구명          경도         위도        지점명  \
# 0        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295  역삼아레나빌딩
# 1        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   논현역사거리
# 2        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295  신사역성일빌딩
# 3        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   국기원사거리
# 4        MA010120220805286683  컴포즈커피  도봉구  127.039395  37.640295   대치재경빌딩
# ...                       ...    ...  ...         ...        ...        ...
# 1481035  MA010120220806486938    이디야  광진구  127.078984  37.555582      상봉역
# 1481036  MA010120220806486938    이디야  광진구  127.078984  37.555582       묵동
# 1481037  MA010120220806486938    이디야  광진구  127.078984  37.555582      망우동
# 1481038  MA010120220806486938    이디야  광진구  127.078984  37.555582      양원역
# 1481039  MA010120220806486938    이디야  광진구  127.078984  37.555582      중화역
#
#                                           지점주소       지점위도        지점경도  \
# 0                      서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1                     서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2                     서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3                     서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4                   서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583
# ...                                        ...        ...         ...
# 1481035                서울특별시 중랑구 망우로 307 (상봉동)  37.596890  127.086470
# 1481036  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368  127.076633
# 1481037                서울특별시 중랑구 망우로 407 (망우동)  37.599508  127.097539
# 1481038              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654  127.106360
# 1481039                   서울특별시 중랑구 봉화산로 35 1층  37.601709  127.078411
#
#                    거리
# 0        15482.665721
# 1        14547.334678
# 2        14148.328859
# 3        15669.332830
# 4        16321.499492
# ...               ...
# 1481035   4640.350019
# 1481036   6651.101626
# 1481037   5150.800506
# 1481038   6170.035990
# 1481039   5129.323416
#
# [1481040 rows x 10 columns]

# %%
# 개별 매장들과 스타벅스와의 최소 거리
df_dis = df_cross.groupby(['상가업소번호','상호명'])['거리'].min().reset_index()
df_dis
# Out:
#                     상가업소번호    상호명           거리
# 0     MA010120220800021713  컴포즈커피   692.058445
# 1     MA010120220800024620    이디야    95.740366
# 2     MA010120220800026176    이디야  1115.073437
# 3     MA010120220800033480    이디야    81.912918
# 4     MA010120220800033806    이디야   352.787720
# ...                    ...    ...          ...
# 2239  MA0106202505A0037502   메가커피    95.224950
# 2240  MA0106202505A0037503   메가커피   140.321135
# 2241  MA0106202505A2290022   올리브영   126.269649
# 2242  MA0106202505A2290025   올리브영    50.867055
# 2243  MA0106202505A2290033   올리브영     1.436596
#
# [2244 rows x 3 columns]

# %%
df_dis.groupby('상호명')['거리'].mean()
# Out:
# 상호명
# 메가커피     378.765455
# 빽다방      301.636549
# 올리브영     228.705689
# 이디야      385.526853
# 컴포즈커피    344.478792
# Name: 거리, dtype: float64

# %%
# agg(): 다중 집계작업을 간단하게 해주는 함수
df_dis.groupby(['상호명'])['거리'].agg(['mean', 'count'])
# Out:
#              mean  count
# 상호명
# 메가커피   378.765455    839
# 빽다방    301.636549    370
# 올리브영   228.705689    116
# 이디야    385.526853    479
# 컴포즈커피  344.478792    440

# %%
# 거리를 입력하면 프렌차이즈 별 스타벅스와의 평균거리와 매장개수를 출력하는 함수
def distance(x):
    dis = df_dis['거리'] <= x
    return df_dis[dis].groupby('상호명')['거리'].agg(['mean', 'count'])

distance(100)
# Out:
#             mean  count
# 상호명
# 메가커피   59.826943    149
# 빽다방    64.689504     92
# 올리브영   53.356951     50
# 이디야    66.265859     84
# 컴포즈커피  62.403265     87

# %% [markdown]
# # **5. 차트 시각화**

# %%
# !pip install pandasecharts
# Out:
# Requirement already satisfied: pandasecharts in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (0.5)
# Requirement already satisfied: pandas in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pandasecharts) (2.3.3)
# Requirement already satisfied: pyecharts>=1.0.0 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pandasecharts) (2.0.9)
# Requirement already satisfied: jinja2 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.1.6)
# Requirement already satisfied: prettytable in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.16.0)
# Requirement already satisfied: simplejson in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from jinja2->pyecharts>=1.0.0->pandasecharts) (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pandas->pandasecharts) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ohjih\appdata\roaming\python\python313\site-packages (from pandas->pandasecharts) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ohjih\appdata\local\programs\python\python313\lib\site-packages (from pandas->pandasecharts) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ohjih\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->pandasecharts) (1.17.0)
# Requirement already satisfied: wcwidth in c:\users\ohjih\appdata\roaming\python\python313\site-packages (from prettytable->pyecharts>=1.0.0->pandasecharts) (0.2.14)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_100 = distance(100).reset_index()
df_100
# Out:
#      상호명       mean  count
# 0   메가커피  59.826943    149
# 1    빽다방  64.689504     92
# 2   올리브영  53.356951     50
# 3    이디야  66.265859     84
# 4  컴포즈커피  62.403265     87

# %%
print("rows:", len(df_100))
print(df_100[['상호명','count']].head())  # 존재/값 확인
# Out:
# rows: 5
#      상호명  count
# 0   메가커피    149
# 1    빽다방     92
# 2   올리브영     50
# 3    이디야     84
# 4  컴포즈커피     87

# %%
import IPython
from pandasecharts import echart

df_100.echart.pie(x='상호명', y='count', figsize=(600, 400),
                  radius=['20%', '60%'], label_opts={'position':'outer'},
                  title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                  legend_opts={'pos_right':'0%', 'orient':'vertical'},
                  subtitle='100m 이내 매장수', init_opts={'bg_color': 'white'}).render()

IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="assets/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="7ee731c20bce477895f3a7a40c114313" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_7ee731c20bce477895f3a7a40c114313 = echarts.init(
#             document.getElementById('7ee731c20bce477895f3a7a40c114313'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_7ee731c20bce477895f3a7a40c114313 = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "count",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\uba54\uac00\ucee4\ud53c",
#                     "value": 149
#                 },
#                 {
#                     "name": "\ube7d\ub2e4\ubc29",
#                     "value": 92
#                 },
#                 {
#                     "name": "\uc62c\ub9ac\ube0c\uc601",
#                     "value": 50
#                 },
#                 {
#                     "name": "\uc774\ub514\uc57c",
#                     "value": 84
#                 },
#                 {
#                     "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                     "value": 87
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outer",
#                 "margin": 8,
#                 "formatter": "{b}:{d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uba54\uac00\ucee4\ud53c",
#                 "\ube7d\ub2e4\ubc29",
#                 "\uc62c\ub9ac\ube0c\uc601",
#                 "\uc774\ub514\uc57c",
#                 "\ucef4\ud3ec\uc988\ucee4\ud53c"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "0%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\ucee4\ud53c \ud504\ub80c\ucc28\uc774\uc988\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \uc2a4\ud0c0\ubc85\uc2a4 \uc606\uc778\uac00?",
#             "target": "blank",
#             "subtext": "100m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#         chart_7ee731c20bce477895f3a7a40c114313.setOption(option_7ee731c20bce477895f3a7a40c114313);
#     </script>
# </body>
# </html>

# %%
from pyecharts.charts import Timeline, Grid

tl = Timeline({'width':'600px', 'height':'400px'})

for i in [1000, 100, 50, 30]:
    df_d = distance(i).reset_index()
    pie1 = df_d.echart.pie(x='상호명', y='count', figsize=(600, 400),
                    radius=['20%', '60%'], label_opts={'position':'outer'},
                    title='커피 프렌차이즈의 입점전략은 과연 스타벅스 옆인가?',
                    legend_opts={'pos_right':'0%', 'orient':'vertical'},
                    subtitle='{}m 이내 매장수'.format(i), init_opts={'bg_color': 'white'})
    tl.add(pie1, '{}m'.format(i)).render()
IPython.display.HTML(filename='render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#                 <script type="text/javascript" src="assets/echarts.min.js"></script>
#
#
# </head>
# <body >
#     <div id="13581bb8054744f8b885195ba734bb9d" class="chart-container" style="width:600px; height:400px; "></div>
#     <script>
#         var chart_13581bb8054744f8b885195ba734bb9d = echarts.init(
#             document.getElementById('13581bb8054744f8b885195ba734bb9d'), 'white', {renderer: 'canvas', locale: 'ZH'});
#         var option_13581bb8054744f8b885195ba734bb9d = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "count",
#                 "colorBy": "data",
#                 "legendHoverLink": true,
#                 "selectedMode": false,
#                 "selectedOffset": 10,
#                 "clockwise": true,
#                 "startAngle": 90,
#                 "minAngle": 0,
#                 "minShowLabelAngle": 0,
#                 "avoidLabelOverlap": true,
#                 "stillShowZeroSum": true,
#                 "percentPrecision": 2,
#                 "showEmptyCircle": true,
#                 "emptyCircleStyle": {
#                     "color": "lightgray",
#                     "borderColor": "#000",
#                     "borderWidth": 0,
#                     "borderType": "solid",
#                     "borderDashOffset": 0,
#                     "borderCap": "butt",
#                     "borderJoin": "bevel",
#                     "borderMiterLimit": 10,
#                     "opacity": 1
#                 },
#                 "data": [
#                     {
#                         "name": "\uba54\uac00\ucee4\ud53c",
#                         "value": 22
#                     },
#                     {
#                         "name": "\ube7d\ub2e4\ubc29",
#                         "value": 9
#                     },
#                     {
#                         "name": "\uc62c\ub9ac\ube0c\uc601",
#                         "value": 12
#                     },
#                     {
#                         "name": "\uc774\ub514\uc57c",
#                         "value": 8
#                     },
#                     {
#                         "name": "\ucef4\ud3ec\uc988\ucee4\ud53c",
#                         "value": 13
#                     }
#                 ],
#                 "radius": [
#                     "20%",
#                     "60%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "outer",
#                     "margin": 8,
#                     "formatter": "{b}:{d}%",
#                     "valueAnimation": false
#                 },
#                 "labelLine": {
#                     "show": true,
#                     "showAbove": false,
#                     "length": 15,
#                     "length2": 15,
#                     "smooth": false,
#                     "minTurnAngle": 90,
#                     "maxSurfaceAngle": 90
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "1000m",
#                 "100m",
#                 "50m",
#                 "30m"
#             ]
#         },
#         "legend": [
#             {
#                 "data": [
#                     "\uba54\uac00\ucee4\ud53c",
#                     "\ube7d\ub2e4\ubc29",
#                     "\uc62c\ub9ac\ube0c\uc601",
#                     "\uc774\ub514\uc57c",
#                     "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                 ],
#                 "selected": {},
#                 "show": true,
#                 "right": "0%",
#                 "orient": "vertical",
#                 "padding": 5,
#                 "itemGap": 10,
#                 "itemWidth": 25,
#                 "itemHeight": 14,
#                 "backgroundColor": "transparent",
#                 "borderColor": "#ccc",
#                 "borderRadius": 0,
#                 "pageButtonItemGap": 5,
#                 "pageButtonPosition": "end",
#                 "pageFormatter": "{current}/{total}",
#                 "pageIconColor": "#2f4554",
#                 "pageIconInactiveColor": "#aaa",
#                 "pageIconSize": 15,
#                 "animationDurationUpdate": 800,
#                 "selector": false,
#                 "selectorPosition": "auto",
#                 "selectorItemGap": 7,
#                 "selectorButtonGap": 10
#             }
#         ]
#     },
#     "options": [
#         {
#             "backgroundColor": "white",
#             "legend": [
#                 {
#                     "data": [
#                         "\uba54\uac00\ucee4\ud53c",
#                         "\ube7d\ub2e4\ubc29",
#                         "\uc62c\ub9ac\ube0c\uc601",
#                         "\uc774\ub514\uc57c",
#                         "\ucef4\ud3ec\uc988\ucee4\ud53c"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14,
#                     "backgroundColor": "transparent",
#                     "borderColor": "#ccc",
#                     "borderRadius": 0,
#                     "pageButtonItemGap": 5,
#                     "pageButtonPosition": "end",
#                     "pageFormatter": "{current}/{total}",
#                     "pageIconColor": "#2f4554",
#                     "pageIconInactiveColor": "#aaa",
#                     "pageIconSize": 15,
#                     "animationDurationUpdate": 800,
#                     "selector": false,
#                     "selectorPosition": "auto",
#                     "selectorItemGap": 7,
#                     "selectorButtonGap": 10
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "colorBy": "data",
#                     "legendHoverLink": true,
#                     "selectedMode": false,
#                     "selectedOffset": 10,
#                     "clockwise": true,
#                     "startAngle": 90,
#                     "minAngle": 0,
#                     "minShowLabelAngle": 0,
#                     "avoidLabelOverlap": true,
#                     "stillShowZeroSum": true,
#                     "percentPrecision": 2,
#                     "showEmptyCircle": true,
#                     "emptyCircleStyle": {
#                         "color": "lightgray",
#                         "borderColor": "#000",
#                         "borderWidth": 0,
#                         "borderType": "solid",
#                         "borderDashOffset": 0,
#                         "borderCap": "butt",
#                         "borderJoin": "bevel",
#                         "borderMiterLimit": 10,
#                         "opacity": 1
#                     },
#                     "data": [
#                         {
#                             "name": "\uba54\uac00\ucee4\ud53c",
#                             "value": 791
#                         },
#                         {
#                             "name": "\ube7d\ub2e4\ubc29",
#                             "value": 357
#                         },
#                         {
#                             "name": "\uc62c\ub9ac\ube0c\uc601",
#                             "value": 112
#                         },
#                         {
